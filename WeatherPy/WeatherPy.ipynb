# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats 
from datetime import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv(r"C:\Users\preit\OneDrive\Desktop\python_api_challenge-2\WeatherPy\cities.csv")
# Out:
#   Cell In[2], line 7
#     from scipy.stats
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# #Generate the Cities List by Using the csv

# %%
# Import citipy for finding nearest cities
from citipy import citipy

# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []
# Initialize lists for latitude and humidity
latitudes=[]
humidities = []
temperatures=[]


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 592

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters for logging
record_count = 1
set_count = 1

# Loop through all the cities in the list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create the endpoint URL with the current city
    city_url = f"{url}q={city}&appid={weather_api_key}"

    # Log the URL, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each city
    try:
        # Make the API request and retrieve the data
        city_weather = requests.get(city_url).json()

        # Parse out the relevant data from the response
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the city information into the city_data list
        city_data.append({
            "City": city,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Date": city_date
        })

    # Handle errors if the city is not found
    except:
        print(f"City {city} not found. Skipping...")
        pass

    # Pause to avoid rate limiting from the API
    time.sleep(1)

# Indicate that data loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# Optionally, you can now work with the 'city_data' list
print(city_data)
#
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atafu village
# Processing Record 2 of Set 1 | edinburgh of the seven seas
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | tura
# Processing Record 5 of Set 1 | necochea
# Processing Record 6 of Set 1 | port-aux-francais
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | alotau
# Processing Record 9 of Set 1 | port mathurin
# Processing Record 10 of Set 1 | adamstown
# Processing Record 11 of Set 1 | blackmans bay
# Processing Record 12 of Set 1 | halifax
# Processing Record 13 of Set 1 | villa gesell
# Processing Record 14 of Set 1 | formosa
# Processing Record 15 of Set 1 | ajdabiya
# Processing Record 16 of Set 1 | beyneu
# Processing Record 17 of Set 1 | mount pearl
# Processing Record 18 of Set 1 | fale old settlement
# Processing Record 19 of Set 1 | usinsk
# Processing Record 20 of Set 1 | vernon
# Processing Record 21 of Set 1 | margaret river
# Processing Record 22 of Set 1 | crane
# Processing Record 23 of Set 1 | pemba
# Processing Record 24 of Set 1 | lebu
# Processing Record 25 of Set 1 | puerto natales
# Processing Record 26 of Set 1 | khorixas
# Processing Record 27 of Set 1 | qamdo
# Processing Record 28 of Set 1 | st. john's
# Processing Record 29 of Set 1 | enriquillo
# Processing Record 30 of Set 1 | qianzhou
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | tofol
# Processing Record 33 of Set 1 | queenstown
# Processing Record 34 of Set 1 | waitangi
# Processing Record 35 of Set 1 | vadso
# Processing Record 36 of Set 1 | san antonio del estrecho
# City san antonio del estrecho not found. Skipping...
# Processing Record 37 of Set 1 | mhamid
# Processing Record 38 of Set 1 | utrik
# Processing Record 39 of Set 1 | inarajan village
# Processing Record 40 of Set 1 | porto novo
# Processing Record 41 of Set 1 | thompson
# Processing Record 42 of Set 1 | grytviken
# Processing Record 43 of Set 1 | kayangel
# Processing Record 44 of Set 1 | uvira
# Processing Record 45 of Set 1 | ta`u
# Processing Record 46 of Set 1 | bilibino
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | miri
# Processing Record 50 of Set 1 | kodiak
# Processing Record 0 of Set 2 | ginir
# Processing Record 1 of Set 2 | rongelap
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | san antonio de pale
# Processing Record 4 of Set 2 | longyearbyen
# Processing Record 5 of Set 2 | kill devil hills
# Processing Record 6 of Set 2 | sakchu-up
# Processing Record 7 of Set 2 | hawaiian paradise park
# Processing Record 8 of Set 2 | invercargill
# Processing Record 9 of Set 2 | alibag
# Processing Record 10 of Set 2 | conduaga
# Processing Record 11 of Set 2 | rakops
# Processing Record 12 of Set 2 | la'ie
# Processing Record 13 of Set 2 | ixtapa
# Processing Record 14 of Set 2 | west island
# Processing Record 15 of Set 2 | mong cai
# City mong cai not found. Skipping...
# Processing Record 16 of Set 2 | cargados carajos
# City cargados carajos not found. Skipping...
# Processing Record 17 of Set 2 | zhangye
# Processing Record 18 of Set 2 | avarua
# Processing Record 19 of Set 2 | tobi village
# City tobi village not found. Skipping...
# Processing Record 20 of Set 2 | enewetak
# Processing Record 21 of Set 2 | howrah
# Processing Record 22 of Set 2 | rawai
# Processing Record 23 of Set 2 | montepuez
# Processing Record 24 of Set 2 | punta arenas
# Processing Record 25 of Set 2 | stanley
# Processing Record 26 of Set 2 | ilulissat
# Processing Record 27 of Set 2 | klyuchi
# Processing Record 28 of Set 2 | belmonte
# Processing Record 29 of Set 2 | kattivakkam
# Processing Record 30 of Set 2 | kavaratti
# Processing Record 31 of Set 2 | sandnessjoen
# Processing Record 32 of Set 2 | ares
# Processing Record 33 of Set 2 | zemio
# Processing Record 34 of Set 2 | ghanzi
# Processing Record 35 of Set 2 | murashi
# Processing Record 36 of Set 2 | tangalle
# Processing Record 37 of Set 2 | tsiombe
# Processing Record 38 of Set 2 | santa cruz
# Processing Record 39 of Set 2 | grand falls-windsor
# Processing Record 40 of Set 2 | anadyr
# Processing Record 41 of Set 2 | yerofey pavlovich
# Processing Record 42 of Set 2 | saipan
# Processing Record 43 of Set 2 | tagiura
# Processing Record 44 of Set 2 | ushuaia
# Processing Record 45 of Set 2 | port saint john's
# Processing Record 46 of Set 2 | oriximina
# Processing Record 47 of Set 2 | akrehamn
# Processing Record 48 of Set 2 | nuku'alofa
# Processing Record 49 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 0 of Set 3 | hadibu
# Processing Record 1 of Set 3 | hot springs national park
# City hot springs national park not found. Skipping...
# Processing Record 2 of Set 3 | al kharijah
# Processing Record 3 of Set 3 | agadez
# Processing Record 4 of Set 3 | higuera de zaragoza
# Processing Record 5 of Set 3 | panshi
# Processing Record 6 of Set 3 | ribeira grande
# Processing Record 7 of Set 3 | talnakh
# Processing Record 8 of Set 3 | vuktyl
# Processing Record 9 of Set 3 | iqaluit
# Processing Record 10 of Set 3 | ust-nera
# Processing Record 11 of Set 3 | mili
# Processing Record 12 of Set 3 | isafjordur
# Processing Record 13 of Set 3 | georgetown
# Processing Record 14 of Set 3 | baiyin
# Processing Record 15 of Set 3 | motygino
# Processing Record 16 of Set 3 | moroni
# Processing Record 17 of Set 3 | picota
# Processing Record 18 of Set 3 | mukah
# City mukah not found. Skipping...
# Processing Record 19 of Set 3 | hengyang
# Processing Record 20 of Set 3 | vorgashor
# Processing Record 21 of Set 3 | dudinka
# Processing Record 22 of Set 3 | jamestown
# Processing Record 23 of Set 3 | broken hill
# Processing Record 24 of Set 3 | port alfred
# Processing Record 25 of Set 3 | north platte
# Processing Record 26 of Set 3 | san patricio
# Processing Record 27 of Set 3 | ilanskiy
# Processing Record 28 of Set 3 | nefta
# Processing Record 29 of Set 3 | polyarnyy
# Processing Record 30 of Set 3 | lusambo
# Processing Record 31 of Set 3 | sitka
# Processing Record 32 of Set 3 | whitehorse
# Processing Record 33 of Set 3 | orlov
# Processing Record 34 of Set 3 | tazacorte
# Processing Record 35 of Set 3 | iskateley
# Processing Record 36 of Set 3 | kiunga
# Processing Record 37 of Set 3 | minas de marcona
# Processing Record 38 of Set 3 | saynshand
# Processing Record 39 of Set 3 | bom jesus
# Processing Record 40 of Set 3 | taiohae
# City taiohae not found. Skipping...
# Processing Record 41 of Set 3 | wailua homesteads
# Processing Record 42 of Set 3 | college
# Processing Record 43 of Set 3 | fernley
# Processing Record 44 of Set 3 | port hedland
# Processing Record 45 of Set 3 | nyurba
# Processing Record 46 of Set 3 | lihue
# Processing Record 47 of Set 3 | tanjung pinang
# Processing Record 48 of Set 3 | callao
# Processing Record 49 of Set 3 | touros
# Processing Record 0 of Set 4 | golere
# Processing Record 1 of Set 4 | merizo village
# Processing Record 2 of Set 4 | argo
# Processing Record 3 of Set 4 | alice springs
# Processing Record 4 of Set 4 | dingcheng
# Processing Record 5 of Set 4 | bogorodskoye
# Processing Record 6 of Set 4 | yeppoon
# Processing Record 7 of Set 4 | pariaman
# Processing Record 8 of Set 4 | portland
# Processing Record 9 of Set 4 | bilajer
# Processing Record 10 of Set 4 | sao gabriel
# Processing Record 11 of Set 4 | la ronge
# Processing Record 12 of Set 4 | puerto lempira
# Processing Record 13 of Set 4 | fukuecho
# Processing Record 14 of Set 4 | luganville
# Processing Record 15 of Set 4 | bengkulu
# Processing Record 16 of Set 4 | vila velha
# Processing Record 17 of Set 4 | barra de santo antonio
# Processing Record 18 of Set 4 | petauke
# Processing Record 19 of Set 4 | afaahiti
# Processing Record 20 of Set 4 | badger
# Processing Record 21 of Set 4 | mazagao
# Processing Record 22 of Set 4 | olonkinbyen
# Processing Record 23 of Set 4 | egilsstadir
# Processing Record 24 of Set 4 | berdigestyakh
# Processing Record 25 of Set 4 | canutama
# Processing Record 26 of Set 4 | colares
# Processing Record 27 of Set 4 | brookings
# Processing Record 28 of Set 4 | luanda
# Processing Record 29 of Set 4 | puerto deseado
# Processing Record 30 of Set 4 | port elizabeth
# Processing Record 31 of Set 4 | dokkum
# Processing Record 32 of Set 4 | mantasoa
# Processing Record 33 of Set 4 | little cayman
# City little cayman not found. Skipping...
# Processing Record 34 of Set 4 | avenal
# Processing Record 35 of Set 4 | guiglo
# Processing Record 36 of Set 4 | hibbing
# Processing Record 37 of Set 4 | funafuti
# Processing Record 38 of Set 4 | clarion
# Processing Record 39 of Set 4 | kongolo
# Processing Record 40 of Set 4 | maputo
# Processing Record 41 of Set 4 | takoradi
# Processing Record 42 of Set 4 | tezu
# Processing Record 43 of Set 4 | alenquer
# Processing Record 44 of Set 4 | trenggalek
# Processing Record 45 of Set 4 | daund
# Processing Record 46 of Set 4 | najran
# Processing Record 47 of Set 4 | gaspe
# Processing Record 48 of Set 4 | california
# Processing Record 49 of Set 4 | show low
# Processing Record 0 of Set 5 | kruisfontein
# Processing Record 1 of Set 5 | illizi
# Processing Record 2 of Set 5 | keflavik
# Processing Record 3 of Set 5 | gargalianoi
# Processing Record 4 of Set 5 | bayan nur
# City bayan nur not found. Skipping...
# Processing Record 5 of Set 5 | pamanukan
# Processing Record 6 of Set 5 | papatowai
# Processing Record 7 of Set 5 | nemuro
# Processing Record 8 of Set 5 | haiku-pauwela
# Processing Record 9 of Set 5 | boguchany
# Processing Record 10 of Set 5 | las heras
# Processing Record 11 of Set 5 | oranjemund
# Processing Record 12 of Set 5 | forster
# Processing Record 13 of Set 5 | ca mau
# Processing Record 14 of Set 5 | al bawiti
# Processing Record 15 of Set 5 | alto araguaia
# Processing Record 16 of Set 5 | fada
# Processing Record 17 of Set 5 | tranqueras
# Processing Record 18 of Set 5 | lerwick
# Processing Record 19 of Set 5 | yemva
# Processing Record 20 of Set 5 | nar'yan-mar
# Processing Record 21 of Set 5 | saint-philippe
# Processing Record 22 of Set 5 | pavlovskaya sloboda
# Processing Record 23 of Set 5 | inirida
# Processing Record 24 of Set 5 | carauari
# Processing Record 25 of Set 5 | quellon
# Processing Record 26 of Set 5 | ola
# Processing Record 27 of Set 5 | aral
# Processing Record 28 of Set 5 | tiksi
# Processing Record 29 of Set 5 | yuzhno-kurilsk
# Processing Record 30 of Set 5 | ha tinh
# Processing Record 31 of Set 5 | popondetta
# Processing Record 32 of Set 5 | terekeka
# City terekeka not found. Skipping...
# Processing Record 33 of Set 5 | talne
# Processing Record 34 of Set 5 | karratha
# Processing Record 35 of Set 5 | puerto san carlos
# City puerto san carlos not found. Skipping...
# Processing Record 36 of Set 5 | kalmunai
# Processing Record 37 of Set 5 | awjilah
# Processing Record 38 of Set 5 | ormond-by-the-sea
# Processing Record 39 of Set 5 | new norfolk
# Processing Record 40 of Set 5 | holualoa
# Processing Record 41 of Set 5 | omis
# Processing Record 42 of Set 5 | pitiquito
# Processing Record 43 of Set 5 | saint croix
# Processing Record 44 of Set 5 | thunder bay

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
print(city_data_df.count())
# Out:
# City          559
# Lat           559
# Lng           559
# Max Temp      559
# Humidity      559
# Cloudiness    559
# Wind Speed    559
# Country       559
# Date          559
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    mount pearl  47.5166  -52.7813    270.35        92         100
# 1         kodiak  57.7900 -152.4072    268.88        86           0
# 2  atafu village  -8.5421 -172.5159    301.69        72          56
# 3         rikaze  29.2500   88.8833    283.43         8          31
# 4       bilibino  68.0546  166.4372    238.95        99         100
#
#    Wind Speed Country        Date
# 0        6.17      CA  1738647201
# 1        0.00      US  1738647202
# 2        6.28      TK  1738647203
# 3        0.70      CN  1738647205
# 4        1.83      RU  1738647206

# %%
# Export the City_Data into a csv
import os

# Check if the directory exists, and create it if it doesn't
output_dir = "output_data"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Now save the CSV
city_data_df.to_csv(f"{output_dir}/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          mount pearl  47.5166  -52.7813    270.35        92         100
# 1               kodiak  57.7900 -152.4072    268.88        86           0
# 2        atafu village  -8.5421 -172.5159    301.69        72          56
# 3               rikaze  29.2500   88.8833    283.43         8          31
# 4             bilibino  68.0546  166.4372    238.95        99         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.17      CA  1738647201
# 1              0.00      US  1738647202
# 2              6.28      TK  1738647203
# 3              0.70      CN  1738647205
# 4              1.83      RU  1738647206

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], alpha=.8, edgecolors="k")

#Format date
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Latitude vs. Temperature ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], alpha=.8, edgecolors="k")

#Format date
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Latitude vs. Temperature ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       2 plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], alpha=.8, edgecolors="k")
#       4 #Format date
# ----> 5 date = datetime.now()
#       6 date = date.strftime("%m-%d-%Y")
#       8 # Incorporate the other graph properties
#
# NameError: name 'datetime' is not defined

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity (%) ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Build the scatter plot for latitude vs. wind speed
# ----> 2 plt.scatter(latitudes, wind_speeds, edgecolors="black", alpha=0.75)
#       4 # Incorporate the other graph properties
#       5 plt.title("City Latitude vs. Wind Speed")
#
# NameError: name 'wind_speeds' is not defined

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#regress_values = x_values * slope + intercept
#line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Call the function to create the plot
# ----> 2 plot_linear_regression(
#       3     x=latitudes,
#       4     y=wind_speeds,
#       5     x_label="Latitude",
#       6     y_label="Wind Speed (m/s)",
#       7     title="City Latitude vs. Wind Speed with Linear Regression",
#       8     file_name="output_data/Fig4.png"
#       9 )
#
# NameError: name 'plot_linear_regression' is not defined

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) > 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            ginir   7.1333  40.7000     22.08        47         100
# 3              bam  29.1060  58.3570     38.66        10           0
# 4        marrakesh  31.6315  -8.0083     17.04        72           0
# 6          machico  32.7000 -16.7667     20.40        81          40
# 8           howrah  22.5892  88.3103     36.00        67          40
#
#          Wind Speed Country        Date
# City_ID
# 1              1.53      ET  1718607742
# 3              7.82      IR  1718607769
# 4              3.09      MA  1718607770
# 6              5.66      PT  1718607772
# 8              6.17      IN  1718607544

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# ----> 2 southern_hemi_df=df[df["latitude']<0]"]]
#       4 # Display sample data
#       5 southern_hemi_df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(0,-20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The regression displays a negative relationship between temperature and latitude")
print("In the northern hemisphere, as the latitude increases the distance from the equator increases")
print("As you move away from the equator, the max temperature decreases.")

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The regression displays a sligtly positive relationship between temperature and latitude.")
print("In the southern hemisphere, as the latitude increases the distance from the equator decreases")
print("As you move closer to the equator, the max temperature generally increases.")
# Out:
# The r^2-value is: 0.6720220238897325

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The relationship is slightly positive, though there doesn't appear to be a strong coorelation between humidity and latitude.")
# Out:
# The r^2-value is: 0.007659599322853922

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,25),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The relationship is slightly positive.")
print("Humidity increases as cities get closer to the equator.")
# Out:
# The r^2-value is: 0.00014367159540169783

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and cloudiness.")
# Out:
# The r^2-value is: 0.006456908379763574

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and cloudiness.")
# Out:
# The r^2-value is: 0.018616831531634456

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(15,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and wind speed.")
# Out:
# The r^2-value is: 0.0017236249523139959

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and wind speed.")
# Out:
# The r^2-value is: 0.06495869418886388

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
